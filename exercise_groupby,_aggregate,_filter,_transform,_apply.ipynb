# %% [markdown]
# <a href="https://colab.research.google.com/github/bpunar/PANDAS-EXERCISES/blob/main/exercise_groupby%2C_aggregate%2C_filter%2C_transform%2C_apply.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **28.01.2022**
# ✈

# %% [markdown]
# **aggregate() **

# %%
import numpy as np
import pandas as pd

# %%
rng = np.random.RandomState(0) # I don't understand why this part is not working.
df = pd.DataFrame({'key' : ['A','B', 'C', 'A', 'B' 'C'],
                   'data1' : range(6),
                   'data2' :rng.randint(0, 10, 6)},
                  columns = ['key','data1','data2'])
df

# %%
d = {'key': ['A', 'B', 'C', 'A','B','C'], 'data1': [0, 1, 2, 3, 4, 5], 'data2' : [5, 0, 3, 3 ,7, 9]}
df = pd.DataFrame(data=d)
df
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9

# %%
df.groupby('key') #

# %%
df.groupby('key').aggregate('min') # If I don't specifically specify a column, it applies the function to all columns.
# Out:
#      data1  data2
# key
# A        0      3
# B        1      0
# C        2      3

# %%
df.groupby('key').aggregate('min','max') # Only the first function works here. others will not work. because ( ) is used. Indeed [ ] should have been used.
# Out:
#      data1  data2
# key
# A        0      3
# B        1      0
# C        2      3

# %%
df.groupby('key').aggregate(['min','max']) # Both functions work.
# Out:
#     data1     data2
#       min max   min max
# key
# A       0   3     3   5
# B       1   4     0   7
# C       2   5     3   9

# %%
#df.groupby('key').aggregate('min','max', np.mean) # [] should not forget
df.groupby('key').aggregate(['min','max', np.mean])
# Out:
#     data1          data2
#       min max mean   min max mean
# key
# A       0   3  1.5     3   5  4.0
# B       1   4  2.5     0   7  3.5
# C       2   5  3.5     3   9  6.0

# %%
df.groupby('key').aggregate({'data1' : 'min', # A different aggregate function can be applied to each column.
                             'data2' : 'max'})
# Out:
#      data1  data2
# key
# A        0      5
# B        1      7
# C        2      9

# %%
df.groupby('key').aggregate({'data1' : 'count', # A different aggregate function can be applied to each column.
                             'data2' : 'max'})
# Out:
#      data1  data2
# key
# A        2      5
# B        2      7
# C        2      9

# %%
df.groupby('key').aggregate({'data1' : 'count', # A different aggregate function can be applied to each column.
                             'data2' : np.mean})
# Out:
#      data1  data2
# key
# A        2    4.0
# B        2    3.5
# C        2    6.0

# %%
df.groupby('key').aggregate({'data1' : np.std, # A different aggregate function can be applied to each column.
                             'data2' : np.mean})
# Out:
#        data1  data2
# key
# A    2.12132    4.0
# B    2.12132    3.5
# C    2.12132    6.0

# %% [markdown]
# **FILTER**

# %%
df
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9

# %%
df.groupby('key').std()
# Out:
#        data1     data2
# key
# A    2.12132  1.414214
# B    2.12132  4.949747
# C    2.12132  4.242641

# %%
# function is TRUE only B and C, so A is FALSE
def filter_func(x):
  return x['data2'].std() > 4

# %%
df.groupby('key').filter(filter_func)
# Out:
#   key  data1  data2
# 1   B      1      0
# 2   C      2      3
# 4   B      4      7
# 5   C      5      9

# %%
# display('df', "df.groupby('key').std()", "df.groupby('key').filter(filter_func)") #I don't understand why the tables aren't shown here, but I'm looking into it.
display(df, df.groupby('key').std(), df.groupby('key').filter(filter_func))
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9
#        data1     data2
# key
# A    2.12132  1.414214
# B    2.12132  4.949747
# C    2.12132  4.242641
#   key  data1  data2
# 1   B      1      0
# 2   C      2      3
# 4   B      4      7
# 5   C      5      9

# %%
display(df, df.groupby('key').std(), df.groupby('key').filter(filter_func)) #I don't understand why the tables aren't shown here, but I'm looking into it.
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9
#        data1     data2
# key
# A    2.12132  1.414214
# B    2.12132  4.949747
# C    2.12132  4.242641
#   key  data1  data2
# 1   B      1      0
# 2   C      2      3
# 4   B      4      7
# 5   C      5      9

# %%
a = df.groupby('key').filter(filter_func) # 
a.groupby('key').std()
# Out:
#        data1     data2
# key
# B    2.12132  4.949747
# C    2.12132  4.242641

# %%
df.groupby('key').std() # Shows all the columns by grouping, especially since a column name is not specified.
# Out:
#        data1     data2
# key
# A    2.12132  1.414214
# B    2.12132  4.949747
# C    2.12132  4.242641

# %%
df.groupby('key').aggregate({"data1":np.std}) # If I want to see a single column grouped into itself. where data1 is the column name.
# Out:
#        data1
# key
# A    2.12132
# B    2.12132
# C    2.12132

# %%
df.groupby('key').data1.std() # If I want to see a single column grouped into itself. where data1 is the column name.
# Out:
# key
# A    2.12132
# B    2.12132
# C    2.12132
# Name: data1, dtype: float64

# %% [markdown]
# TRANSFORM

# %%
df
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9

# %%
df.groupby('key').transform(lambda x: x-x.mean())
# mean
# data1: A:1,5 B: 2.5, C:3.5
# data2: A:, B:3.5 C: 6 

#apply x-x.mean
# 0: data1 : (0-1.5=1.5), data2 = (5-4=1)
# 1: data1 : (1-2.5 =-1.5), data2=(0-3.5=-3.5)
#
# Out:
#    data1  data2
# 0   -1.5    1.0
# 1   -1.5   -3.5
# 2   -1.5   -3.0
# 3    1.5   -1.0
# 4    1.5    3.5
# 5    1.5    3.0

# %% [markdown]
# APPLY

# %%
df
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9

# %%
def norm_by_data2(x):
  x['data1'] /= x['data2'].sum()
# x['data1'] = X['data1'] / x['data2'].sum()
  return x

# %%
df.groupby('key').apply(norm_by_data2)
# Out:
#   key     data1  data2
# 0   A  0.000000      5
# 1   B  0.142857      0
# 2   C  0.166667      3
# 3   A  0.375000      3
# 4   B  0.571429      7
# 5   C  0.416667      9

# %%
display(df, df.groupby('key').apply(norm_by_data2))
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9
#   key     data1  data2
# 0   A  0.000000      5
# 1   B  0.142857      0
# 2   C  0.166667      3
# 3   A  0.375000      3
# 4   B  0.571429      7
# 5   C  0.416667      9

# %%
# 0:0/(5+3) = 0
# 1:1/(0+7) = 1 /7 = 0.142857
# 2:2/(3+9) = 2/12 = 0.166667

# %% [markdown]
# Specifying the split key

# %%
df
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9

# %%
L =[0, 1, 0, 1, 2, 0]
display(df, df.groupby(L).sum())
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9
#    data1  data2
# 0      7     17
# 1      4      3
# 2      4      7

# %%
#0: data1:0+2+5 = 7
#0: data2:5+3+9 = 17
#1: data1:1+3 = 4
#1: data2:0+3 = 3
#2: data1:4
#2: data2:7

# %% [markdown]
# Any Python Function

# %%
df
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9

# %%
df2 = df.set_index('key')
df2
# Out:
#      data1  data2
# key
# A        0      5
# B        1      0
# C        2      3
# A        3      3
# B        4      7
# C        5      9

# %%
df2.groupby(str.lower).mean()
# Out:
#    data1  data2
# a    1.5    4.0
# b    2.5    3.5
# c    3.5    6.0

# %%
d = {'key': ['A', 'B', 'C', 'A','B','C'], 'data1': [3, 'B', 2, 'A','B','C'], 'data2' : [5, 2, 'E', 3 ,7, 9]}
mn = pd.DataFrame(data=d)
mn
# Out:
#   key data1 data2
# 0   A     3     5
# 1   B     B     2
# 2   C     2     E
# 3   A     A     3
# 4   B     B     7
# 5   C     C     9

# %%
L =[0, 1, 0, 1, 2, 0]
display(mn.groupby(L).sum())
# Out:
#    key
# 0  ACC
# 1   BA
# 2    B
