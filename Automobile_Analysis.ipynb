# %% [markdown]
# <a href="https://colab.research.google.com/github/bpunar/PANDAS-EXERCISES/blob/main/Automobile_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df0 = pd.read_csv("Automobile_data.csv")
df = df0.copy()

# %%
df.head(5)
# Out:
#    index      company   body-style  ...  horsepower  average-mileage    price
# 0      0  alfa-romero  convertible  ...         111               21  13495.0
# 1      1  alfa-romero  convertible  ...         111               21  16500.0
# 2      2  alfa-romero    hatchback  ...         154               19  16500.0
# 3      3         audi        sedan  ...         102               24  13950.0
# 4      4         audi        sedan  ...         115               18  17450.0
#
# [5 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             61 non-null     int64
#  1   company           61 non-null     object
#  2   body-style        61 non-null     object
#  3   wheel-base        61 non-null     float64
#  4   length            61 non-null     float64
#  5   engine-type       61 non-null     object
#  6   num-of-cylinders  61 non-null     object
#  7   horsepower        61 non-null     int64
#  8   average-mileage   61 non-null     int64
#  9   price             58 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 4.9+ KB

# %%
df.describe().T
# Out:
#                  count          mean           std  ...      50%      75%      max
# index             61.0     40.885246     25.429706  ...     39.0     61.0     88.0
# wheel-base        61.0     98.481967      6.679234  ...     96.3    101.2    120.9
# length            61.0    173.098361     14.021846  ...    171.2    177.3    208.1
# horsepower        61.0    107.852459     53.524398  ...    100.0    123.0    288.0
# average-mileage   61.0     25.803279      8.129821  ...     25.0     31.0     47.0
# price             58.0  15387.000000  11320.259841  ...  11095.0  18120.5  45400.0
#
# [6 rows x 8 columns]

# %%
df.describe(include="all").T
# Out:
#                  count unique     top freq  ...     25%      50%      75%      max
# index             61.0    NaN     NaN  NaN  ...    18.0     39.0     61.0     88.0
# company             61     16  toyota    7  ...     NaN      NaN      NaN      NaN
# body-style          61      5   sedan   32  ...     NaN      NaN      NaN      NaN
# wheel-base        61.0    NaN     NaN  NaN  ...    94.5     96.3    101.2    120.9
# length            61.0    NaN     NaN  NaN  ...   159.1    171.2    177.3    208.1
# engine-type         61      7     ohc   46  ...     NaN      NaN      NaN      NaN
# num-of-cylinders    61      7    four   39  ...     NaN      NaN      NaN      NaN
# horsepower        61.0    NaN     NaN  NaN  ...    68.0    100.0    123.0    288.0
# average-mileage   61.0    NaN     NaN  NaN  ...    19.0     25.0     31.0     47.0
# price             58.0    NaN     NaN  NaN  ...  6808.5  11095.0  18120.5  45400.0
#
# [10 rows x 11 columns]

# %%
df.describe(include=['O']).T
# Out:
#                  count unique     top freq
# company             61     16  toyota    7
# body-style          61      5   sedan   32
# engine-type         61      7     ohc   46
# num-of-cylinders    61      7    four   39

# %%
df.isnull().sum()
# Out:
# index               0
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               3
# dtype: int64

# %%
df_columns = df.columns
df_columns
# Out:
# Index(['index', 'company', 'body-style', 'wheel-base', 'length', 'engine-type',
#        'num-of-cylinders', 'horsepower', 'average-mileage', 'price'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    index      company   body-style  ...  horsepower  average-mileage    price
# 0      0  alfa-romero  convertible  ...         111               21  13495.0
# 1      1  alfa-romero  convertible  ...         111               21  16500.0
# 2      2  alfa-romero    hatchback  ...         154               19  16500.0
# 3      3         audi        sedan  ...         102               24  13950.0
# 4      4         audi        sedan  ...         115               18  17450.0
# 5      5         audi        sedan  ...         110               19  15250.0
# 6      6         audi        wagon  ...         110               19  18920.0
# 7      9          bmw        sedan  ...         101               23  16430.0
# 8     10          bmw        sedan  ...         101               23  16925.0
# 9     11          bmw        sedan  ...         121               21  20970.0
#
# [10 rows x 10 columns]

# %%
for col in df_columns:
    print(col)
    print("--"*5)
    print(df[col].value_counts(dropna=False))
    print("--"*10)
# Out:
# index
# ----------
# 0     1
# 43    1
# 45    1
# 46    1
# 47    1
#      ..
# 34    1
# 35    1
# 36    1
# 37    1
# 88    1
# Name: index, Length: 61, dtype: int64
# --------------------
# company
# ----------
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# audi             4
# mercedes-benz    4
# mitsubishi       4
# volkswagen       4
# alfa-romero      3
# chevrolet        3
# honda            3
# isuzu            3
# jaguar           3
# porsche          3
# dodge            2
# volvo            2
# Name: company, dtype: int64
# --------------------
# body-style
# ----------
# sedan          32
# hatchback      15
# wagon           9
# convertible     3
# hardtop         2
# Name: body-style, dtype: int64
# --------------------
# wheel-base
# ----------
# 94.5     9
# 95.7     6
# 97.3     4
# 93.7     4
# 101.2    3
# 110.0    3
# 93.1     3
# 96.5     3
# 88.6     2
# 113.0    2
# 89.5     2
# 96.3     2
# 104.3    2
# 103.5    2
# ...

# %%
df.dropna(subset = ["price"], inplace=True)
df
# Out:
#     index        company   body-style  ...  horsepower  average-mileage    price
# 0       0    alfa-romero  convertible  ...         111               21  13495.0
# 1       1    alfa-romero  convertible  ...         111               21  16500.0
# 2       2    alfa-romero    hatchback  ...         154               19  16500.0
# 3       3           audi        sedan  ...         102               24  13950.0
# 4       4           audi        sedan  ...         115               18  17450.0
# 5       5           audi        sedan  ...         110               19  15250.0
# 6       6           audi        wagon  ...         110               19  18920.0
# 7       9            bmw        sedan  ...         101               23  16430.0
# 8      10            bmw        sedan  ...         101               23  16925.0
# 9      11            bmw        sedan  ...         121               21  20970.0
# 10     13            bmw        sedan  ...         182               16  30760.0
# ...

# %% [markdown]
# the most expensive and the most cheapest car company name and their price

# %%
df.loc[(df.price==df['price'].max()) | (df.price==df['price'].min()), ['company','price']]
# Out:
#           company    price
# 13      chevrolet   5151.0
# 35  mercedes-benz  45400.0

# %% [markdown]
# Toyota Cars details

# %%
car_Manufacturers = df.groupby('company')
toyotaDf = car_Manufacturers.get_group('toyota')
toyotaDf
# Out:
#     index company body-style  ...  horsepower  average-mileage    price
# 48     66  toyota  hatchback  ...          62               35   5348.0
# 49     67  toyota  hatchback  ...          62               31   6338.0
# 50     68  toyota  hatchback  ...          62               31   6488.0
# 51     69  toyota      wagon  ...          62               31   6918.0
# 52     70  toyota      wagon  ...          62               27   7898.0
# 53     71  toyota      wagon  ...          62               27   8778.0
# 54     79  toyota      wagon  ...         156               19  15750.0
#
# [7 rows x 10 columns]

# %%
Toyota_df = df.loc[(df.company =="toyota")]
Toyota_df
# Out:
#     index company body-style  ...  horsepower  average-mileage    price
# 48     66  toyota  hatchback  ...          62               35   5348.0
# 49     67  toyota  hatchback  ...          62               31   6338.0
# 50     68  toyota  hatchback  ...          62               31   6488.0
# 51     69  toyota      wagon  ...          62               31   6918.0
# 52     70  toyota      wagon  ...          62               27   7898.0
# 53     71  toyota      wagon  ...          62               27   8778.0
# 54     79  toyota      wagon  ...         156               19  15750.0
#
# [7 rows x 10 columns]

# %% [markdown]
# each company’s Higesht price car

# %%
highest_car = pd.DataFrame(df.groupby("company")['price'].max())
highest_car.reset_index()
# Out:
#           company    price
# 0     alfa-romero  16500.0
# 1            audi  18920.0
# 2             bmw  41315.0
# 3       chevrolet   6575.0
# 4           dodge   6377.0
# 5           honda  12945.0
# 6           isuzu   6785.0
# 7          jaguar  36000.0
# 8           mazda  18344.0
# 9   mercedes-benz  45400.0
# 10     mitsubishi   8189.0
# 11         nissan  13499.0
# 12        porsche  37028.0
# 13         toyota  15750.0
# 14     volkswagen   9995.0
# 15          volvo  13415.0

# %% [markdown]
# the average mileage of each car making company

# %%
df.head(1)
# Out:
#    index      company   body-style  ...  horsepower  average-mileage    price
# 0      0  alfa-romero  convertible  ...         111               21  13495.0
#
# [1 rows x 10 columns]

# %%
ave_mileage	= pd.DataFrame(df.groupby("company")['average-mileage'].mean())
ave_mileage.reset_index()
# Out:
#           company  average-mileage
# 0     alfa-romero        20.333333
# 1            audi        20.000000
# 2             bmw        19.000000
# 3       chevrolet        41.000000
# 4           dodge        31.000000
# 5           honda        26.333333
# 6           isuzu        24.000000
# 7          jaguar        14.333333
# 8           mazda        28.000000
# 9   mercedes-benz        18.000000
# 10     mitsubishi        29.500000
# 11         nissan        31.400000
# 12        porsche        17.000000
# 13         toyota        28.714286
# 14     volkswagen        31.750000
# 15          volvo        23.000000

# %%
df.sort_values(by="price")
# Out:
#     index        company   body-style  ...  horsepower  average-mileage    price
# 13     16      chevrolet    hatchback  ...          48               47   5151.0
# 27     36          mazda    hatchback  ...          68               30   5195.0
# 48     66         toyota    hatchback  ...          62               35   5348.0
# 36     49     mitsubishi    hatchback  ...          68               37   5389.0
# 28     37          mazda    hatchback  ...          68               31   6095.0
# 37     50     mitsubishi    hatchback  ...          68               31   6189.0
# 17     20          dodge    hatchback  ...          68               31   6229.0
# 14     17      chevrolet    hatchback  ...          70               38   6295.0
# 49     67         toyota    hatchback  ...          62               31   6338.0
# 16     19          dodge    hatchback  ...          68               31   6377.0
# 50     68         toyota    hatchback  ...          62               31   6488.0
# ...
